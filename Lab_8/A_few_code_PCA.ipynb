# %%
import os
import numpy as np
import cv2 as cv
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from tqdm.notebook import tnrange

# %%
img_path = "./images/Dat_Face.jpg"

# %%
img = cv.cvtColor(cv.imread(img_path), cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
pcas = {}
for i in tnrange(chl):
    pcas[i] = {"pca":PCA(n_components=10)}
    pcas[i].update({"archive":pcas[i]["pca"].fit_transform(img[:,:,i])})
    pcas[i].update({"dearchive":pcas[i]["pca"].inverse_transform(pcas[i]["archive"])})
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
new_img =  cv.merge([pcas[i]["dearchive"]/255 for i in range(chl)])

# %%
plt.imshow(new_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
