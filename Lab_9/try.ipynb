# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
y_true = [0, 1, 0, 0, 1, 0, 0]
y_pred = [0, 1, 1, 0, 0, 1, 1]

# %%
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.4523809523809524

# %%
d = confusion_matrix(y_true, y_pred)
d
# Out:
# array([[2, 3],
#        [1, 1]], dtype=int64)

# %%
k = ConfusionMatrixDisplay(d)
k.plot()

# %%
import sklearn.datasets as datasets
import pandas as pd

# %%
X,y = datasets.load_wine(return_X_y=True, as_frame=True)

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int32

# %%
df = X.copy()
df["label"]=y

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.20        1.76  2.45               15.2      112.0           3.27
# 1      13.36        2.56  2.35               20.0       89.0           1.40
# 2      12.37        1.63  2.30               24.5       88.0           2.22
# 3      13.73        4.36  2.26               22.5       88.0           1.28
# 4      12.88        2.99  2.40               20.0      104.0           1.30
# ..       ...         ...   ...                ...        ...            ...
# 173    13.88        1.89  2.59               15.0      101.0           3.25
# 174    12.33        1.10  2.28               16.0      101.0           2.05
# 175    13.23        3.30  2.28               18.5       98.0           1.80
# 176    12.00        1.51  2.42               22.0       86.0           1.45
# 177    13.45        3.70  2.60               23.0      111.0           1.70
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.39                  0.34             1.97             6.75  1.05
# 1          0.50                  0.37             0.64             5.60  0.70
# 2          2.45                  0.40             1.90             2.12  0.89
# 3          0.47                  0.52             1.15             6.62  0.78
# 4          1.22                  0.24             0.83             5.40  0.74
# ..          ...                   ...              ...              ...   ...
# 173        3.56                  0.17             1.70             5.43  0.88
# 174        1.09                  0.63             0.41             3.27  1.25
# 175        0.83                  0.61             1.87            10.52  0.56
# 176        1.25                  0.50             1.63             3.60  1.05
# 177        0.92                  0.43             1.46            10.68  0.85
#
#      od280/od315_of_diluted_wines  proline  label
# 0                            2.85   1450.0      0
# 1                            2.47    780.0      2
# 2                            2.78    342.0      1
# 3                            1.75    520.0      2
# 4                            1.42    530.0      2
# ..                            ...      ...    ...
# 173                          3.56   1095.0      0
# 174                          1.67    680.0      1
# 175                          1.51    675.0      2
# 176                          2.65    450.0      1
# 177                          1.56    695.0      2
#
# [178 rows x 14 columns]
